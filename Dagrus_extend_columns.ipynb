# %%
import pandas as pd
import re
import os

# %%
dagrus = pd.read_csv("dagrus.csv")
dagrus.head()
# Out:
#      Recoding_name   Speaker_id  Beginning  Ending  \
# 0  2009-Khiv-2.eaf  Interviewer       6738    7600
# 1  2009-Khiv-2.eaf  Interviewer       7913    8383
# 2  2009-Khiv-2.eaf  Interviewer       8748   10941
# 3  2009-Khiv-2.eaf  Interviewer      15770   17702
# 4  2009-Khiv-2.eaf  Interviewer      21043   21513
#
#                               Transcript  Category Note  Unnamed: 7 Unnamed: 8
# 0                                    Угу…      NaN  NaN         NaN        NaN
# 1                                    Поэ=      NaN  NaN         NaN        NaN
# 2  поэтому русский так хорошо знаете, да?      NaN  NaN         NaN        NaN
# 3        В школе на русском языке учился?      NaN  NaN         NaN        NaN
# 4                                     Да?      NaN  NaN         NaN        NaN

# %%
df = dagrus.drop('Unnamed: 7', 1)

# %%
df.head()
# Out:
#      Recoding_name   Speaker_id  Beginning  Ending  \
# 0  2009-Khiv-2.eaf  Interviewer       6738    7600
# 1  2009-Khiv-2.eaf  Interviewer       7913    8383
# 2  2009-Khiv-2.eaf  Interviewer       8748   10941
# 3  2009-Khiv-2.eaf  Interviewer      15770   17702
# 4  2009-Khiv-2.eaf  Interviewer      21043   21513
#
#                               Transcript  Category Note Unnamed: 8
# 0                                    Угу…      NaN  NaN        NaN
# 1                                    Поэ=      NaN  NaN        NaN
# 2  поэтому русский так хорошо знаете, да?      NaN  NaN        NaN
# 3        В школе на русском языке учился?      NaN  NaN        NaN
# 4                                     Да?      NaN  NaN        NaN

# %%
df = df.drop('Unnamed: 8', 1)
df.head()
# Out:
#      Recoding_name   Speaker_id  Beginning  Ending  \
# 0  2009-Khiv-2.eaf  Interviewer       6738    7600
# 1  2009-Khiv-2.eaf  Interviewer       7913    8383
# 2  2009-Khiv-2.eaf  Interviewer       8748   10941
# 3  2009-Khiv-2.eaf  Interviewer      15770   17702
# 4  2009-Khiv-2.eaf  Interviewer      21043   21513
#
#                               Transcript  Category Note
# 0                                    Угу…      NaN  NaN
# 1                                    Поэ=      NaN  NaN
# 2  поэтому русский так хорошо знаете, да?      NaN  NaN
# 3        В школе на русском языке учился?      NaN  NaN
# 4                                     Да?      NaN  NaN

# %%
dag_rus = df

# %% [markdown]
# Use textgrid parser instead of this crap

# %%
path='D:\\MyDocuments\\Intonation Project\\Mehweb-3'
for el in os.listdir(path=path):
    f = open(path + "\\" + el, "r")
    s = f.readlines()
    for line in s:
        if re.search('tori', line):
        if re.search('illocutive type', line):
# Out:
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# юяFile type = "ooTextFile"
# ...

# %% [markdown]
# https://github.com/hschen0712/textgrid-parser
